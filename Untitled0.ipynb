# %% [markdown]
# <a href="https://colab.research.google.com/github/Coxinha0013/POO---28-08/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Veiculo:
    def __init__(self, marca, modelo):
        self.marca = marca
        self.modelo = modelo
        self.ligado = False

    def ligar(self):
        self.ligado = True
        return f"{self.marca} {self.modelo} está ligado."

    def desligar(self):
        self.ligado = False
        return f"{self.marca} {self.modelo} está desligado."

    def acelerar(self):
        if self.ligado:
            return f"{self.marca} {self.modelo} está acelerando."
        else:
            return f"Não é possível acelerar. {self.marca} {self.modelo} está desligado."

    def __str__(self):
        estado = "ligado" if self.ligado else "desligado"
        return f"{self.marca} {self.modelo} está {estado}."

class Carro(Veiculo): #Herdando de Veiculo
    def __init__(self, marca, modelo, portas):
        super().__init__(marca, modelo)
        self.portas = portas

    def porta_malas(self):
        return f"O porta-malas do {self.marca} {self.modelo} está aberto."

    def acelerar(self):
        if self.ligado:
            return f"O carro {self.marca} {self.modelo} está acelerando muito rápido!"
        else:
            return f"Não é possível acelerar. O carro {self.marca} {self.modelo} está desligado."

    def __str__(self):
        return f"{self.marca} {self.modelo}, {self.portas} portas, está {'ligado' if self.ligado else 'desligado'}."

class Moto(Veiculo):
    def __init__(self, marca, modelo, cilindradas):
        super().__init__(marca, modelo)
        self.cilindradas = cilindradas

    def grau(self):
        if self.ligado:
            return f"A moto {self.marca} {self.modelo} está dando grau!"
        else:
            return f"Não é possível dar grau. A moto {self.marca} {self.modelo} está desligada."

    def acelerar(self):
        if self.ligado:
            return f"A moto {self.marca} {self.modelo} está acelerando muito rápido!"
        else:
            return f"Não é possível acelerar. A moto {self.marca} {self.modelo} está desligada."

    def __str__(self):

        return f"{self.marca} {self.modelo}, {self.cilindradas} cilindradas, está {'ligado' if self.ligado else 'desligado'}."

class Eletro(Veiculo):
    def __init__(self, marca, modelo, autonomia):
        super().__init__(marca, modelo)
        self.autonomia = autonomia
        self.carga = 100

    def carregar(self):
        self.carga = 100

        return f"O {self.modelo} está totalmente carregado."

    def autonomia_restante(self):

        return f"O {self.modelo} tem {self.carga}% de carga restante."

class Patins(Eletro):
    def __init__(self, marca, modelo, autonomia):
        super().__init__(marca, modelo, autonomia)

    def acelerar(self):
        if self.ligado and self.carga > 0:
            self.carga -= 10

            return f"O patins elétrico {self.marca} {self.modelo} está acelerando!"
        elif self.ligado and self.carga <= 0:
            return f"O patins {self.marca} {self.modelo} está sem carga. Por favor, carregue-o."
        else:
            return f"Não é possível acelerar. O patins {self.marca} {self.modelo} está desligado."

# Código principal para testar

if __name__ == "__main__":
    print("--- Veúculos ---")
    veiculo1 = Veiculo("Chevrolet", "Celta")
    print(veiculo1)
    veiculo1.ligar()
    print(veiculo1.acelerar())
    veiculo1.desligar()
    print(veiculo1)
    print()

    print(" --- Carro ---")
    carro1 = Carro("Ford", "EcoSport", 4)
    print(carro1)
    carro1.ligar()
    print(carro1.acelerar())
    carro1.porta_malas()
    carro1.desligar()
    print(carro1)
    print()

    print(" --- Moto ---")
    moto1 = Moto("Honda", "CB 500", 500)
    print(moto1)
    moto1.ligar()
    print(moto1.acelerar())
    print(moto1.grau())
    moto1.desligar()
    print(moto1)
    print()

    print(" --- Patins Elétrico ---")
    patins1 = Patins("Xiaomi", "Mi Electric Scooter 3", 30)
    print(patins1)
    patins1.ligar()
    print(patins1.autonomia_restante())
    print(patins1.acelerar())
    print(patins1.autonomia_restante())
    print(patins1.carregar())
    patins1.desligar()
    print(patins1)
    print()
    print("--- Polimorfismo ---")
    veiculo1 = Veiculo("Chevrolet", "Celta")
    carro1 = Carro("Ford", "EcoSport", 4)
    moto1 = Moto("Honda", "CB 500", 500)
    patins1 = Patins("Xiaomi", "Mi Electric Scooter 3", 30)

    veiculos = [veiculo1, carro1, moto1, patins1]

    for veiculo in veiculos:
        print(veiculo.ligar())

    print(f"\n--- Acelerando todos os veículos ---")
    for veiculo in veiculos:
        print(veiculo.acelerar())
# Out:
# --- Veúculos ---
# Chevrolet Celta está desligado.
# Chevrolet Celta está acelerando.
# Chevrolet Celta está desligado.
#
#  --- Carro ---
# Ford EcoSport, 4 portas, está desligado.
# O carro Ford EcoSport está acelerando muito rápido!
# Ford EcoSport, 4 portas, está desligado.
#
#  --- Moto ---
# Honda CB 500, 500 cilindradas, está desligado.
# A moto Honda CB 500 está acelerando muito rápido!
# A moto Honda CB 500 está dando grau!
# Honda CB 500, 500 cilindradas, está desligado.
#
#  --- Patins Elétrico ---
# Xiaomi Mi Electric Scooter 3 está desligado.
# O Mi Electric Scooter 3 tem 100% de carga restante.
# O patins elétrico Xiaomi Mi Electric Scooter 3 está acelerando!
# O Mi Electric Scooter 3 tem 90% de carga restante.
# O Mi Electric Scooter 3 está totalmente carregado.
# Xiaomi Mi Electric Scooter 3 está desligado.
#
# --- Polimorfismo ---
# Chevrolet Celta está ligado.
# Ford EcoSport está ligado.
# Honda CB 500 está ligado.
# Xiaomi Mi Electric Scooter 3 está ligado.
#
# --- Acelerando todos os veículos ---
# Chevrolet Celta está acelerando.
# O carro Ford EcoSport está acelerando muito rápido!
# A moto Honda CB 500 está acelerando muito rápido!
# O patins elétrico Xiaomi Mi Electric Scooter 3 está acelerando!
